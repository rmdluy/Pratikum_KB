# %%
import pandas as pd
import numpy as np

df = pd.read_csv("fifa_eda_stats.csv")
Data = {
    'jumlah_record' :0,
    'nama_atribut' :[],
    'atribut_objek' :0,
    'atribt_angka' :0,
    'atribut_null' :0,
}
Data['jumlah_record'] = df.shape[0]
Data['nama_atribut'] = list(df.columns.values)
Data['atribut_objek'] = list(df.select_dtypes(['object']).columns)
Data['atribut_angka'] = list(df.select_dtypes(['float64', 'int64']).columns)
Data['atribut_null'] = list(df.loc[:, df.isnull().any()].columns)

# %%
print ("jumlah record pada dataset :",Data['jumlah_record'])
# Out:
# jumlah record pada dataset : 18207

# %%
print ("Nama Atribute :", Data['nama_atribut'])
print ("Jumlah Atribut :", len(Data['nama_atribut']))
# Out:
# Nama Atribute : ['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause']
# Jumlah Atribut : 57

# %%
print ("Atribut dengan tipe objek :", Data['atribut_objek'], len(Data['atribut_objek']))
# Out:
# Atribut dengan tipe objek : ['Name', 'Nationality', 'Club', 'Value', 'Wage', 'Preferred Foot', 'Work Rate', 'Body Type', 'Position', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'Release Clause'] 15

# %%
print ("Atribut dengan Tipe Angka :", Data['atribut_angka'], len(Data['atribut_angka']))
# Out:
# Atribut dengan Tipe Angka : ['ID', 'Age', 'Overall', 'Potential', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'] 42

# %%
print ("Atribut dengan Nilai Null :", Data['atribut_null'], len(Data['atribut_null']))
# Out:
# Atribut dengan Nilai Null : ['Club', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'] 49

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential  \
# count   18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299
# std     29965.244204      4.669943      6.908930      6.136496
# min        16.000000     16.000000     46.000000     48.000000
# 25%    200315.500000     21.000000     62.000000     67.000000
# 50%    221759.000000     25.000000     66.000000     71.000000
# 75%    236529.500000     28.000000     71.000000     75.000000
# max    246620.000000     45.000000     94.000000     95.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                 ID       Age   Overall  Potential  \
# ID                        1.000000 -0.739208 -0.417025   0.047074
# Age                      -0.739208  1.000000  0.452350  -0.253312
# Overall                  -0.417025  0.452350  1.000000   0.660939
# Potential                 0.047074 -0.253312  0.660939   1.000000
# International Reputation -0.356191  0.253765  0.499491   0.372993
# Weak Foot                -0.075784  0.059867  0.212015   0.162346
# Skill Moves              -0.056914  0.027649  0.414463   0.354290
# Jersey Number             0.182074 -0.241156 -0.218931  -0.010474
# Crossing                 -0.131994  0.130545  0.394972   0.246319
# Finishing                -0.082323  0.068660  0.332515   0.243355
# HeadingAccuracy          -0.106815  0.147183  0.340776   0.200988
# ShortPassing             -0.136279  0.132894  0.502550   0.369189
# Volleys                  -0.159915  0.142472  0.391338   0.254906
# ...

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                        object
# Wage                         object
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Body Type                    object
# Position                     object
# Jersey Number               float64
# Joined                       object
# Loaned From                  object
# Contract Valid Until         object
# Height                       object
# Weight                       object
# Crossing                    float64
# Finishing                   float64
# HeadingAccuracy             float64
# ShortPassing                float64
# ...

# %%
df['Overall'] = df['Overall'].astype('float64')

# %%
df.head(10)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina     94.0         94
# 1   20801  Cristiano Ronaldo   33    Portugal     94.0         94
# 2  190871          Neymar Jr   26      Brazil     92.0         93
# 3  193080             De Gea   27       Spain     91.0         93
# 4  192985       K. De Bruyne   27     Belgium     91.0         92
# 5  183277          E. Hazard   27     Belgium     91.0         91
# 6  177003          L. Modrić   32     Croatia     91.0         91
# 7  176580          L. Suárez   31     Uruguay     91.0         91
# 8  155862       Sergio Ramos   32       Spain     91.0         91
# 9  200389           J. Oblak   25    Slovenia     90.0         93
#
#                   Club    Value   Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  €110.5M  €565K           Left  ...       96.0
# 1             Juventus     €77M  €405K          Right  ...       95.0
# ...

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                     float64
# Potential                     int64
# Club                         object
# Value                        object
# Wage                         object
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Body Type                    object
# Position                     object
# Jersey Number               float64
# Joined                       object
# Loaned From                  object
# Contract Valid Until         object
# Height                       object
# Weight                       object
# Crossing                    float64
# Finishing                   float64
# HeadingAccuracy             float64
# ShortPassing                float64
# ...

# %%
dh = df.select_dtypes(include=np.number)
dh.head(10)
# Out:
#        ID  Age  Overall  Potential  International Reputation  Weak Foot  \
# 0  158023   31     94.0         94                       5.0        4.0
# 1   20801   33     94.0         94                       5.0        4.0
# 2  190871   26     92.0         93                       5.0        5.0
# 3  193080   27     91.0         93                       4.0        3.0
# 4  192985   27     91.0         92                       4.0        5.0
# 5  183277   27     91.0         91                       4.0        4.0
# 6  177003   32     91.0         91                       4.0        4.0
# 7  176580   31     91.0         91                       5.0        4.0
# 8  155862   32     91.0         91                       4.0        3.0
# 9  200389   25     90.0         93                       3.0        3.0
#
#    Skill Moves  Jersey Number  Crossing  Finishing  ...  Penalties  Composure  \
# 0          4.0           10.0      84.0       95.0  ...       75.0       96.0
# ...

# %%
df[['ID', 'Age', 'Overall', 'Potential', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']].to_csv("dataset atribut bertipe angka.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  float64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     18207 non-null  object
#  8   Wage                      18207 non-null  object
#  9   Preferred Foot            18159 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Weak Foot                 18159 non-null  float64
#  12  Skill Moves               18159 non-null  float64
# ...
